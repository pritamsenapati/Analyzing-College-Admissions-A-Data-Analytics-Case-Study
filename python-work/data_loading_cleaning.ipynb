# %%
import sys
print(sys.executable)
# Out:
# c:\Users\senap\OneDrive\Documents\Desktop\venv\Scripts\python.exe

# %%
import sys
# !{sys.executable} -m pip install matplotlib seaborn
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.11.0-cp314-cp314-win_amd64.whl.metadata (80 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.63.0-cp314-cp314-win_amd64.whl.metadata (121 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.5.0-cp314-cp314-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.25 in c:\Users\senap\OneDrive\Documents\Desktop\venv\Lib\site-packages (from matplotlib) (2.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\Users\senap\OneDrive\Documents\Desktop\venv\Lib\site-packages (from matplotlib) (26.2)
# Collecting pillow>=9 (from matplotlib)
#   Using cached pillow-12.3.0-cp314-cp314-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\senap\OneDrive\Documents\Desktop\venv\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\Users\senap\OneDrive\Documents\Desktop\venv\Lib\site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: tzdata in c:\Users\senap\OneDrive\Documents\Desktop\venv\Lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\Users\senap\OneDrive\Documents\Desktop\venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached matplotlib-3.11.0-cp314-cp314-win_amd64.whl (9.5 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached contourpy-1.3.3-cp314-cp314-win_amd64.whl (232 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.63.0-cp314-cp314-win_amd64.whl (2.3 MB)
# Using cached kiwisolver-1.5.0-cp314-cp314-win_amd64.whl (75 kB)
# Using cached pillow-12.3.0-cp314-cp314-win_amd64.whl (7.2 MB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
#
#    ---------------------------------------- 0/8 [pyparsing]
#    ---------------------------------------- 0/8 [pyparsing]
#    ---------------------------------------- 0/8 [pyparsing]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    ------------------------- -------------- 5/8 [contourpy]
#    ------------------------- -------------- 5/8 [contourpy]
#    ------------------------- -------------- 5/8 [contourpy]
#    ------------------------- -------------- 5/8 [contourpy]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ---------------------------------------- 8/8 [seaborn]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.11.0 pillow-12.3.0 pyparsing-3.3.2 seaborn-0.13.2

# %%
import matplotlib.pyplot as plt
import seaborn as sns

print("Matplotlib:", plt.matplotlib.__version__)
print("Seaborn:", sns.__version__)
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Matplotlib: 3.11.0
# Seaborn: 0.13.2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("Ai_student_350000_rows.csv")

# %%
df.head(3)
# Out:
#    student_id  age gender     state  family_income  high_school_gpa  \
# 0           1   22   Male      Ohio          32560              3.2
# 1           2   19   Male  Virginia          39084              4.0
# 2           3   20   Male      Ohio          21615              2.9
#
#    sat_score  act_score  attendance_rate  ap_courses  extracurricular_count  \
# 0        734         27             91.0           3                      3
# 1        988         26            100.0           0                      5
# 2       1600         28             97.7           2                      3
#
#    volunteer_hours  leadership_positions  coding_projects  social_media_hours  \
# 0               85                     1                4                 4.8
# 1              103                     1                4                 2.7
# 2               78                     2                1                 5.4
#
#    online_certifications  essay_score  recommendation_score  interview_score  \
# 0                      1         96.3                  90.5             71.7
# 1                      2         59.9                  55.2             93.0
# 2                      4         75.2                  70.3             70.0
#
#    admission_status
# 0                 1
# 1                 1
# 2                 1

# %%
df.tail()
# Out:
#         student_id  age gender       state  family_income  high_school_gpa  \
# 349995      349996   17   Male    New York          72423             2.92
# 349996      349997   16   Male     Florida          59909             3.07
# 349997      349998   22   Male  California          61378             2.62
# 349998      349999   22   Male     Florida         157800             3.36
# 349999      350000   17   Male     Georgia          46944             3.12
#
#         sat_score  act_score  attendance_rate  ap_courses  \
# 349995       1335         15            100.0           4
# 349996        873         21             93.6           3
# 349997        762         27             91.9           4
# 349998       1113         29             91.2           4
# 349999       1083         25             91.3           3
#
#         extracurricular_count  volunteer_hours  leadership_positions  \
# 349995                      4              105                     4
# 349996                      6              223                     1
# 349997                      5              219                     2
# 349998                      4               63                     2
# 349999                      1              119                     0
#
#         coding_projects  social_media_hours  online_certifications  \
# 349995                4                 3.9                      0
# 349996                2                 4.8                      1
# 349997                3                 2.5                      2
# 349998                3                 2.1                      0
# 349999                3                 6.8                      2
#
#         essay_score  recommendation_score  interview_score  admission_status
# 349995         67.0                  91.3             77.6                 1
# 349996         78.0                  75.9             82.9                 1
# 349997         75.0                  75.2             53.7                 1
# 349998         75.0                  86.3             74.1                 1
# 349999         78.2                  71.1             95.5                 1

# %%
df.sample(5)
# Out:
#         student_id  age  gender       state  family_income  high_school_gpa  \
# 206934      206935   16    Male       Texas          62888             2.84
# 33723        33724   18    Male    New York         354210             3.03
# 343084      343085   19    Male    Virginia          56336             3.07
# 311677      311678   21  Female  California          54147             2.78
# 220450      220451   18  Female    New York          37027             2.57
#
#         sat_score  act_score  attendance_rate  ap_courses  \
# 206934        975         29             87.5           3
# 33723        1265         29             92.7           3
# 343084        982         21             82.7           1
# 311677        771         35             86.4           3
# 220450       1285         30             82.9           0
#
#         extracurricular_count  volunteer_hours  leadership_positions  \
# 206934                      2               88                     1
# 33723                       2              123                     0
# 343084                      3              125                     1
# 311677                      3               57                     3
# 220450                      2              172                     0
#
#         coding_projects  social_media_hours  online_certifications  \
# 206934                2                 2.8                      3
# 33723                 8                 4.9                      1
# 343084                4                 6.3                      0
# 311677                2                 1.2                      5
# 220450                1                 5.9                      0
#
#         essay_score  recommendation_score  interview_score  admission_status
# 206934         84.9                  87.8             78.4                 1
# 33723          98.9                  70.4             57.5                 1
# 343084         75.2                  94.8             73.5                 1
# 311677         65.3                  80.0            100.0                 1
# 220450         46.1                  72.2            100.0                 1

# %%
df.shape
# Out:
# (350000, 20)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 350000 entries, 0 to 349999
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   student_id             350000 non-null  int64
#  1   age                    350000 non-null  int64
#  2   gender                 350000 non-null  str
#  3   state                  350000 non-null  str
#  4   family_income          350000 non-null  int64
#  5   high_school_gpa        350000 non-null  float64
#  6   sat_score              350000 non-null  int64
#  7   act_score              350000 non-null  int64
#  8   attendance_rate        350000 non-null  float64
#  9   ap_courses             350000 non-null  int64
#  10  extracurricular_count  350000 non-null  int64
#  11  volunteer_hours        350000 non-null  int64
#  12  leadership_positions   350000 non-null  int64
#  13  coding_projects        350000 non-null  int64
#  14  social_media_hours     350000 non-null  float64
#  15  online_certifications  350000 non-null  int64
#  16  essay_score            350000 non-null  float64
#  17  recommendation_score   350000 non-null  float64
#  18  interview_score        350000 non-null  float64
#  19  admission_status       350000 non-null  int64
# dtypes: float64(6), int64(12), str(2)
# memory usage: 53.4 MB

# %%
df.describe()
# Out:
#           student_id            age  family_income  high_school_gpa  \
# count  350000.000000  350000.000000  350000.000000    350000.000000
# mean   175000.500000      18.999734   71607.001997         3.188966
# std    101036.441446       1.999141   46995.521498         0.475727
# min         1.000000      16.000000    2124.000000         0.920000
# 25%     87500.750000      17.000000   39974.750000         2.860000
# 50%    175000.500000      19.000000   59887.000000         3.200000
# 75%    262500.250000      21.000000   89617.000000         3.540000
# max    350000.000000      22.000000  929368.000000         4.000000
#
#            sat_score      act_score  attendance_rate     ap_courses  \
# count  350000.000000  350000.000000    350000.000000  350000.000000
# mean     1099.231323      23.479440        91.743662       2.996763
# std       217.073393       5.909284         5.530772       1.727524
# min       400.000000       1.000000        63.200000       0.000000
# 25%       952.000000      19.000000        87.900000       2.000000
# 50%      1101.000000      24.000000        92.000000       3.000000
# 75%      1248.000000      28.000000        96.000000       4.000000
# max      1600.000000      36.000000       100.000000      12.000000
#
#        extracurricular_count  volunteer_hours  leadership_positions  \
# count          350000.000000    350000.000000         350000.000000
# mean                3.998489        99.414966              1.203394
# std                 2.000893        49.975726              1.096511
# min                 0.000000         2.000000              0.000000
# 25%                 3.000000        63.000000              0.000000
# 50%                 4.000000        91.000000              1.000000
# 75%                 5.000000       127.000000              2.000000
# max                15.000000       478.000000              8.000000
#
#        coding_projects  social_media_hours  online_certifications  \
# count    350000.000000       350000.000000          350000.000000
# mean          2.002691            4.503291               1.996254
# std           1.416895            1.787770               1.415565
# min           0.000000            0.000000               0.000000
# 25%           1.000000            3.300000               1.000000
# 50%           2.000000            4.500000               2.000000
# 75%           3.000000            5.700000               3.000000
# max          11.000000           12.900000              12.000000
#
#          essay_score  recommendation_score  interview_score  admission_status
# count  350000.000000         350000.000000    350000.000000     350000.000000
# mean       74.899586             77.950741        72.742962          0.881626
# std        11.805339              9.892415        14.522410          0.323051
# min        21.700000             29.100000         8.500000          0.000000
# 25%        66.900000             71.200000        62.800000          1.000000
# 50%        75.000000             78.000000        72.900000          1.000000
# 75%        83.100000             84.700000        83.100000          1.000000
# max       100.000000            100.000000       100.000000          1.000000

# %%
df.isnull().sum()
# Out:
# student_id               0
# age                      0
# gender                   0
# state                    0
# family_income            0
# high_school_gpa          0
# sat_score                0
# act_score                0
# attendance_rate          0
# ap_courses               0
# extracurricular_count    0
# volunteer_hours          0
# leadership_positions     0
# coding_projects          0
# social_media_hours       0
# online_certifications    0
# essay_score              0
# recommendation_score     0
# interview_score          0
# admission_status         0
# dtype: int64

# %%
(df.isnull().sum()/len(df))*100
# Out:
# student_id               0.0
# age                      0.0
# gender                   0.0
# state                    0.0
# family_income            0.0
# high_school_gpa          0.0
# sat_score                0.0
# act_score                0.0
# attendance_rate          0.0
# ap_courses               0.0
# extracurricular_count    0.0
# volunteer_hours          0.0
# leadership_positions     0.0
# coding_projects          0.0
# social_media_hours       0.0
# online_certifications    0.0
# essay_score              0.0
# recommendation_score     0.0
# interview_score          0.0
# admission_status         0.0
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# student_id               350000
# age                           7
# gender                        3
# state                        10
# family_income            131486
# high_school_gpa             286
# sat_score                  1201
# act_score                    36
# attendance_rate             323
# ap_courses                   13
# extracurricular_count        16
# volunteer_hours             409
# leadership_positions          9
# coding_projects              12
# social_media_hours          122
# online_certifications        13
# essay_score                 715
# recommendation_score        613
# interview_score             848
# admission_status              2
# dtype: int64

# %%
df.dtypes
# Out:
# student_id                 int64
# age                        int64
# gender                       str
# state                        str
# family_income              int64
# high_school_gpa          float64
# sat_score                  int64
# act_score                  int64
# attendance_rate          float64
# ap_courses                 int64
# extracurricular_count      int64
# volunteer_hours            int64
# leadership_positions       int64
# coding_projects            int64
# social_media_hours       float64
# online_certifications      int64
# essay_score              float64
# recommendation_score     float64
# interview_score          float64
# admission_status           int64
# dtype: object

# %%
df["gender"].unique()
# Out:
# <StringArray>
# ['Male', 'Female', 'Other']
# Length: 3, dtype: str

# %%
df["state"].unique()
# Out:
# <StringArray>
# [          'Ohio',       'Virginia',       'Illinois',        'Florida',
#      'California',       'New York', 'North Carolina',          'Texas',
#         'Georgia',     'Washington']
# Length: 10, dtype: str

# %%
df["admission_status"].unique()
# Out:
# array([1, 0])

# %%
numerical_columns = df.select_dtypes(include=np.number).columns
numerical_columns
# Out:
# Index(['student_id', 'age', 'family_income', 'high_school_gpa', 'sat_score',
#        'act_score', 'attendance_rate', 'ap_courses', 'extracurricular_count',
#        'volunteer_hours', 'leadership_positions', 'coding_projects',
#        'social_media_hours', 'online_certifications', 'essay_score',
#        'recommendation_score', 'interview_score', 'admission_status'],
#       dtype='str')

# %%
for col in numerical_columns:
    plt.figure(figsize=(6,2))
    sns.boxplot(x=df[col])
    plt.title(col)
    plt.show()

# %%
df_clean = df.drop(columns=["student_id"])

# %%
df_clean.to_csv("college_admission_clean.csv", index=False)
